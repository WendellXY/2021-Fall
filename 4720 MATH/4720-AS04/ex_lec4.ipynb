# %%
import csv

# %%
# test csv reader and peek the dataset
with open('db_lec4.txt', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter='\t')
    for row in reader:
        print(",".join(row))
# Out:
# Pt,BP,Age,Weight,BSA,Dur,Pulse,Stress
# 1,105,47,85.4,1.75,5.1,63,33
# 2,115,49,94.2,2.10,3.8,70,14
# 3,116,49,95.3,1.98,8.2,72,10
# 4,117,50,94.7,2.01,5.8,73,99
# 5,112,51,89.4,1.89,7.0,72,95
# 6,121,48,99.5,2.25,9.3,71,10
# 7,121,49,99.8,2.25,2.5,69,42
# 8,110,47,90.9,1.90,6.2,66,8
# 9,110,49,89.2,1.83,7.1,69,62
# 10,114,48,92.7,2.07,5.6,64,35
# 11,114,47,94.4,2.07,5.3,74,90
# 12,115,49,94.1,1.98,5.6,71,21
# 13,114,50,91.6,2.05,10.2,68,47
# 14,106,45,87.1,1.92,5.6,67,80
# 15,125,52,101.3,2.19,10.0,76,98
# 16,114,46,94.5,1.98,7.4,69,95
# 17,106,46,87.0,1.87,3.6,62,18
# 18,113,46,94.5,1.90,4.3,70,12
# 19,110,48,90.5,1.88,9.0,71,99
# 20,122,56,95.7,2.09,7.0,75,99

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('db_lec4.txt', delimiter='\t')
df
# Out:
#     Pt   BP  Age  Weight   BSA   Dur  Pulse  Stress
# 0    1  105   47    85.4  1.75   5.1     63      33
# 1    2  115   49    94.2  2.10   3.8     70      14
# 2    3  116   49    95.3  1.98   8.2     72      10
# 3    4  117   50    94.7  2.01   5.8     73      99
# 4    5  112   51    89.4  1.89   7.0     72      95
# 5    6  121   48    99.5  2.25   9.3     71      10
# 6    7  121   49    99.8  2.25   2.5     69      42
# 7    8  110   47    90.9  1.90   6.2     66       8
# 8    9  110   49    89.2  1.83   7.1     69      62
# 9   10  114   48    92.7  2.07   5.6     64      35
# 10  11  114   47    94.4  2.07   5.3     74      90
# 11  12  115   49    94.1  1.98   5.6     71      21
# 12  13  114   50    91.6  2.05  10.2     68      47
# 13  14  106   45    87.1  1.92   5.6     67      80
# 14  15  125   52   101.3  2.19  10.0     76      98
# 15  16  114   46    94.5  1.98   7.4     69      95
# 16  17  106   46    87.0  1.87   3.6     62      18
# ...

# %%
df.corr()
# Out:
#               Pt        BP       Age    Weight       BSA       Dur     Pulse  \
# Pt      1.000000  0.031135  0.042694  0.024857 -0.031288  0.176246  0.112285
# BP      0.031135  1.000000  0.659093  0.950068  0.865879  0.292834  0.721413
# Age     0.042694  0.659093  1.000000  0.407349  0.378455  0.343792  0.618764
# Weight  0.024857  0.950068  0.407349  1.000000  0.875305  0.200650  0.659340
# BSA    -0.031288  0.865879  0.378455  0.875305  1.000000  0.130540  0.464819
# Dur     0.176246  0.292834  0.343792  0.200650  0.130540  1.000000  0.401514
# Pulse   0.112285  0.721413  0.618764  0.659340  0.464819  0.401514  1.000000
# Stress  0.343152  0.163901  0.368224  0.034355  0.018446  0.311640  0.506310
#
#           Stress
# Pt      0.343152
# BP      0.163901
# Age     0.368224
# Weight  0.034355
# BSA     0.018446
# Dur     0.311640
# Pulse   0.506310
# Stress  1.000000

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_fe38b_row0_col0,#T_fe38b_row1_col1,#T_fe38b_row2_col2,#T_fe38b_row3_col3,#T_fe38b_row4_col4,#T_fe38b_row5_col5,#T_fe38b_row6_col6,#T_fe38b_row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_fe38b_row0_col1,#T_fe38b_row0_col2,#T_fe38b_row0_col3,#T_fe38b_row0_col4,#T_fe38b_row0_col6,#T_fe38b_row4_col0,#T_fe38b_row4_col5,#T_fe38b_row4_col7{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_fe38b_row0_col5,#T_fe38b_row3_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_fe38b_row0_col7{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_fe38b_row1_col0{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_fe38b_row1_col2{
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }#T_fe38b_row1_col3,#T_fe38b_row3_col1{
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = pd.DataFrame()

# %%
vif_data["feature"] = df.columns

# %%
vif_data["VIF"] = [variance_inflation_factor(df.values, i) 
                   for i in range(len(df.columns))]

# %%
print(vif_data)
# Out:
#   feature           VIF
# 0      Pt      5.304970
# 1      BP  41936.549706
# 2     Age   3112.352730
# 3  Weight  22617.025732
# 4     BSA   1617.891583
# 5     Dur     14.680941
# 6   Pulse   1691.763967
# 7  Stress      7.512732

# %%
lba = np.linalg.eig(corr)[0]

# %%
mcn = max(lba) / min(lba)
mcn
# Out:
# 1818.2344678567126

# %% [markdown]
# Since MCN is large than 1000, so the dataset have very series issue.
